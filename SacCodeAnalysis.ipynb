# %%
# importing needed packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#read in csv
sac_data = pd.read_csv("sacstation1.csv")
# Out:
# /var/folders/_r/k4drv0q16vb4s0cfjxzhbc180000gn/T/ipykernel_53782/4161668466.py:2: DtypeWarning: Columns (9,10,11,12,13,14,17,18,19,20,25,28,46,47,48,49,50,58,59) have mixed types. Specify dtype option on import or set low_memory=False.
#   sac_data = pd.read_csv("sacstation1.csv")

# %%
sac_data.head(5)
# Out:
#        STATION                     NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0  USW00023271  SACRAMENTO 5 ESE, CA US   38.5552  -121.4183       11.6
# 1  USW00023271  SACRAMENTO 5 ESE, CA US   38.5552  -121.4183       11.6
# 2  USW00023271  SACRAMENTO 5 ESE, CA US   38.5552  -121.4183       11.6
# 3  USW00023271  SACRAMENTO 5 ESE, CA US   38.5552  -121.4183       11.6
# 4  USW00023271  SACRAMENTO 5 ESE, CA US   38.5552  -121.4183       11.6
#
#                   DATE REPORT_TYPE  SOURCE  CoolingDegreeDaysSeasonToDate  \
# 0  1877-07-11T00:00:00         SOD     NaN                            NaN
# 1  1877-07-12T00:00:00         SOD     NaN                            NaN
# 2  1877-07-13T00:00:00         SOD     NaN                            NaN
# 3  1877-07-14T00:00:00         SOD     NaN                            NaN
# 4  1877-07-15T00:00:00         SOD     NaN                            NaN
#
#   DailyAverageDryBulbTemperature  ... MonthlyNumberDaysWithSnowfall  \
# ...

# %%
# print all column names
for col in sac_data.columns:
    print(col)
# Out:
# STATION
# NAME
# LATITUDE
# LONGITUDE
# ELEVATION
# DATE
# REPORT_TYPE
# SOURCE
# CoolingDegreeDaysSeasonToDate
# DailyAverageDryBulbTemperature
# DailyCoolingDegreeDays
# DailyDepartureFromNormalAverageTemperature
# DailyHeatingDegreeDays
# DailyMaximumDryBulbTemperature
# DailyMinimumDryBulbTemperature
# DailyPeakWindDirection
# DailyPeakWindSpeed
# DailyPrecipitation
# DailySnowDepth
# DailySnowfall
# DailyWeather
# HeatingDegreeDaysSeasonToDate
# HourlyDewPointTemperature
# HourlyDryBulbTemperature
# HourlyPrecipitation
# HourlyPresentWeatherType
# HourlyRelativeHumidity
# HourlySeaLevelPressure
# HourlySkyConditions
# HourlyStationPressure
# HourlyWetBulbTemperature
# HourlyWindDirection
# HourlyWindSpeed
# MonthlyCoolingDegreeDays
# MonthlyDaysWithGT001Precip
# MonthlyDaysWithGT010Precip
# MonthlyDaysWithGT32Temp
# MonthlyDaysWithGT90Temp
# MonthlyDaysWithLT0Temp
# MonthlyDaysWithLT32Temp
# MonthlyDepartureFromNormalAverageTemperature
# ...

# %%
#select columns of relevant interest
selected_sac_columns = ["STATION", "NAME", "DATE", "REPORT_TYPE", "HourlyDryBulbTemperature", "HourlyPrecipitation", "HourlySkyConditions","MonthlyNumberDaysWithHeavyFog"]

selected_sac_data = sac_data[selected_sac_columns]
selected_sac_data
# Out:
#             STATION                     NAME                 DATE REPORT_TYPE  \
# 0       USW00023271  SACRAMENTO 5 ESE, CA US  1877-07-11T00:00:00         SOD
# 1       USW00023271  SACRAMENTO 5 ESE, CA US  1877-07-12T00:00:00         SOD
# 2       USW00023271  SACRAMENTO 5 ESE, CA US  1877-07-13T00:00:00         SOD
# 3       USW00023271  SACRAMENTO 5 ESE, CA US  1877-07-14T00:00:00         SOD
# 4       USW00023271  SACRAMENTO 5 ESE, CA US  1877-07-15T00:00:00         SOD
# ...             ...                      ...                  ...         ...
# 113599  USW00023271  SACRAMENTO 5 ESE, CA US  2025-05-29T00:00:00         SOD
# 113600  USW00023271  SACRAMENTO 5 ESE, CA US  2025-05-30T00:00:00         SOD
# 113601  USW00023271  SACRAMENTO 5 ESE, CA US  2025-05-31T00:00:00         SOD
# 113602  USW00023271  SACRAMENTO 5 ESE, CA US  2025-05-31T23:59:00         SOM
# 113603  USW00023271  SACRAMENTO 5 ESE, CA US  2025-06-01T00:00:00         SOD
#
# ...

# %%
# Look at missing values
missing_data_rows = selected_sac_data[selected_sac_data.isna().any(axis=1)]
missing_data_rows
# Out:
#             STATION                     NAME                 DATE REPORT_TYPE  \
# 0       USW00023271  SACRAMENTO 5 ESE, CA US  1877-07-11T00:00:00         SOD
# 1       USW00023271  SACRAMENTO 5 ESE, CA US  1877-07-12T00:00:00         SOD
# 2       USW00023271  SACRAMENTO 5 ESE, CA US  1877-07-13T00:00:00         SOD
# 3       USW00023271  SACRAMENTO 5 ESE, CA US  1877-07-14T00:00:00         SOD
# 4       USW00023271  SACRAMENTO 5 ESE, CA US  1877-07-15T00:00:00         SOD
# ...             ...                      ...                  ...         ...
# 113599  USW00023271  SACRAMENTO 5 ESE, CA US  2025-05-29T00:00:00         SOD
# 113600  USW00023271  SACRAMENTO 5 ESE, CA US  2025-05-30T00:00:00         SOD
# 113601  USW00023271  SACRAMENTO 5 ESE, CA US  2025-05-31T00:00:00         SOD
# 113602  USW00023271  SACRAMENTO 5 ESE, CA US  2025-05-31T23:59:00         SOM
# 113603  USW00023271  SACRAMENTO 5 ESE, CA US  2025-06-01T00:00:00         SOD
#
# ...

# %%
just_columns = ["HourlyDryBulbTemperature", "HourlyPrecipitation", "HourlySkyConditions","MonthlyNumberDaysWithHeavyFog"]

columns_sac_data = sac_data[just_columns]
columns_sac_data
# Out:
#         HourlyDryBulbTemperature  HourlyPrecipitation HourlySkyConditions  \
# 0                            NaN                  NaN                 NaN
# 1                            NaN                  NaN                 NaN
# 2                            NaN                  NaN                 NaN
# 3                            NaN                  NaN                 NaN
# 4                            NaN                  NaN                 NaN
# ...                          ...                  ...                 ...
# 113599                       NaN                  NaN                 NaN
# 113600                       NaN                  NaN                 NaN
# 113601                       NaN                  NaN                 NaN
# 113602                       NaN                  NaN                 NaN
# 113603                       NaN                  NaN                 NaN
#
#         MonthlyNumberDaysWithHeavyFog
# 0                                 NaN
# ...

# %%
#all of them????
other_data_rows = columns_sac_data[columns_sac_data.notna().any(axis=1)]
print(other_data_rows)
# Out:
#         HourlyDryBulbTemperature  HourlyPrecipitation HourlySkyConditions  \
# 5829                         5.6                  NaN                 NaN
# 5830                         5.6                  NaN                 NaN
# 5831                         7.3                  NaN                 NaN
# 5832                         7.3                  NaN                 NaN
# 5834                         4.4                  NaN                 NaN
# ...                          ...                  ...                 ...
# 113193                       NaN                  0.5                 NaN
# 113309                       NaN                  0.3                 NaN
# 113310                       NaN                  0.3                 NaN
# 113311                       NaN                  0.3                 NaN
# 113312                       NaN                  0.3                 NaN
#
#         MonthlyNumberDaysWithHeavyFog
# 5829                              NaN
# ...

# %%
just_fog = sac_data["MonthlyNumberDaysWithHeavyFog"]
print(just_fog)
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 113599   NaN
# 113600   NaN
# 113601   NaN
# 113602   NaN
# 113603   NaN
# Name: MonthlyNumberDaysWithHeavyFog, Length: 113604, dtype: float64

# %%
just_fog_rows = just_fog[just_fog.notna()]
print(just_fog_rows)
# Out:
# 110362    1.0
# Name: MonthlyNumberDaysWithHeavyFog, dtype: float64
